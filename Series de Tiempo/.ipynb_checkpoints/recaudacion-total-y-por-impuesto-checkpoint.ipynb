# %% [markdown]
# ### Práctica adicional - Recaudación SPN
#
# Llamo las librerias pandas y matplotlib que voy a utilizar en el ejemplo.

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# Con el objetivo de mostrar la evolución de la Recaudación del Sector Público Nacional y los componentes más influyentes en los períodos analizados:
#
# 1) Llamamos a las series de interés en un sólo link utilizando los recursos de la API.

# %%
#Genero la variable reca_total con la info en csv original de la página datos.gob.ar. 
reca_total= pd.read_csv("https://apis.datos.gob.ar/series/api/series/?ids=172.3_TL_RECAION_M_0_0_17,452.2_APORTES_COIAL_0_T_39_29,452.2_BIENES_PERLES_0_T_17_26,452.2_COMBUSTIBLLES_0_T_12_97,452.2_DEBITOS_CRTOS_0_T_16_22,452.2_DERECHOS_EION_0_T_20_42,452.2_DERECHOS_IION_0_T_20_60,452.2_GANANCIASIAS_0_T_9_51,452.2_IMPUESTOS_NOS_0_T_18_87,452.2_INGRESOS_CTAL_0_T_16_75,452.2_IVA_NETO_RROS_0_T_19_67,452.2_RESTO_RENTDAD_0_T_22_24,452.2_RESTO_TRIBIOS_0_T_17_0,452.2_RESTO_RENTDAD_0_T_22_24&limit=5000&format=csv")
reca_total
# Out:
#     indice_tiempo  total_recaudacion  aportes_contribuciones_seguridad_social  \
# 0      1997-01-01        4353.758957                                      NaN
# 1      1997-02-01        3634.762208                                      NaN
# 2      1997-03-01        3531.360254                                      NaN
# 3      1997-04-01        3939.777343                                      NaN
# 4      1997-05-01        4600.930508                                      NaN
# 5      1997-06-01        3908.607791                                      NaN
# 6      1997-07-01        4136.127521                                      NaN
# 7      1997-08-01        4009.268688                                      NaN
# 8      1997-09-01        4083.262520                                      NaN
# 9      1997-10-01        3961.872102                                      NaN
# 10     1997-11-01        4117.013021                                      NaN
# 11     1997-12-01        4250.573705                                      NaN
# 12     1998-01-01        4153.836209                                      NaN
# 13     1998-02-01        3928.501359                                      NaN
# 14     1998-03-01        3888.021595                                      NaN
# 15     1998-04-01        3899.389178                                      NaN
# 16     1998-05-01        4703.723851                                      NaN
# 17     1998-06-01        4617.985122                                      NaN
# 18     1998-07-01        4390.899776                                      NaN
# 19     1998-08-01        4188.354610                                      NaN
# 20     1998-09-01        3980.194710                                      NaN
# 21     1998-10-01        3973.510455                                      NaN
# 22     1998-11-01        4030.312631                                      NaN
# 23     1998-12-01        4281.813561                                      NaN
# 24     1999-01-01        4179.716609                                      NaN
# 25     1999-02-01        3753.379159                                      NaN
# 26     1999-03-01        3904.796095                                      NaN
# 27     1999-04-01        3807.621749                                      NaN
# 28     1999-05-01        4166.509435                                      NaN
# 29     1999-06-01        4179.103854                                      NaN
# ..            ...                ...                                      ...
# 242    2017-03-01      212294.842190                                  54312.1
# 243    2017-04-01      187948.992009                                  56286.1
# 244    2017-05-01      206055.392051                                  57241.6
# 245    2017-06-01      226592.654031                                  53914.9
# 246    2017-07-01      237325.846818                                  77910.7
# 247    2017-08-01      221275.374480                                  58459.2
# 248    2017-09-01      224065.555024                                  60213.5
# 249    2017-10-01      219713.325774                                  62464.6
# 250    2017-11-01      224463.756560                                  62414.6
# 251    2017-12-01      235238.459930                                  64872.2
# 252    2018-01-01      261961.041107                                  86641.7
# 253    2018-02-01      235666.267400                                  67189.8
# 254    2018-03-01      238835.950697                                  69224.6
# 255    2018-04-01      236227.302723                                  70874.8
# 256    2018-05-01      295420.934187                                  69709.3
# 257    2018-06-01      298853.292893                                  70828.8
# 258    2018-07-01      293893.988533                                  92571.3
# 259    2018-08-01      293418.406094                                  71779.1
# 260    2018-09-01      295817.643577                                  72740.5
# 261    2018-10-01      312508.826852                                  75837.1
# 262    2018-11-01      300119.367372                                  77447.2
# 263    2018-12-01      319921.455095                                  77077.9
# 264    2019-01-01      363926.997702                                 111561.0
# 265    2019-02-01      330890.720986                                  88625.3
# 266    2019-03-01      327869.711878                                  87168.6
# 267    2019-04-01      357362.276227                                 100634.1
# 268    2019-05-01      444249.747767                                  92507.3
# 269    2019-06-01      454442.137431                                  94352.3
# 270    2019-07-01      450909.802147                                 128786.6
# 271    2019-08-01      458494.598304                                      NaN
#
#      bienes_personales  combustibles  debitos_creditos  derechos_exportacion  \
# 0                  NaN           NaN               NaN                   NaN
# 1                  NaN           NaN               NaN                   NaN
# 2                  NaN           NaN               NaN                   NaN
# 3                  NaN           NaN               NaN                   NaN
# 4                  NaN           NaN               NaN                   NaN
# 5                  NaN           NaN               NaN                   NaN
# 6                  NaN           NaN               NaN                   NaN
# 7                  NaN           NaN               NaN                   NaN
# 8                  NaN           NaN               NaN                   NaN
# 9                  NaN           NaN               NaN                   NaN
# 10                 NaN           NaN               NaN                   NaN
# 11                 NaN           NaN               NaN                   NaN
# 12                 NaN           NaN               NaN                   NaN
# 13                 NaN           NaN               NaN                   NaN
# 14                 NaN           NaN               NaN                   NaN
# 15                 NaN           NaN               NaN                   NaN
# 16                 NaN           NaN               NaN                   NaN
# 17                 NaN           NaN               NaN                   NaN
# 18                 NaN           NaN               NaN                   NaN
# 19                 NaN           NaN               NaN                   NaN
# 20                 NaN           NaN               NaN                   NaN
# 21                 NaN           NaN               NaN                   NaN
# 22                 NaN           NaN               NaN                   NaN
# 23                 NaN           NaN               NaN                   NaN
# 24                 NaN           NaN               NaN                   NaN
# 25                 NaN           NaN               NaN                   NaN
# 26                 NaN           NaN               NaN                   NaN
# 27                 NaN           NaN               NaN                   NaN
# 28                 NaN           NaN               NaN                   NaN
# 29                 NaN           NaN               NaN                   NaN
# ..                 ...           ...               ...                   ...
# 242              198.6        2772.7           10941.1                5875.1
# 243              487.1        4520.7           10817.7                9223.4
# 244              217.0        3676.3           10758.3                6162.2
# 245             1740.6        3734.0           12153.7                5419.4
# 246             1340.3        3702.8           12252.3                7620.9
# 247             1050.0        3729.3           12028.6                6450.1
# 248              965.7        3396.4           13199.8                4811.6
# 249             1041.0        3219.4           11792.1                3740.5
# 250              361.6        3144.2           12947.6                4073.7
# 251              836.3        4748.0           11725.6                5138.4
# 252              249.9        2274.4           19130.3                2707.5
# 253              245.4        3066.3           13733.7                3926.7
# 254              735.3        2699.3           16212.5                2130.2
# 255              223.2        3315.1           17938.4                5313.6
# 256              238.2        4297.3           18695.2                8202.3
# 257             1426.8        3706.6           19793.7                8294.8
# 258              485.5        3999.6           18383.7                4656.0
# 259              723.4        4523.1           20351.1                4170.2
# 260              308.4        3833.3           21832.2               12694.8
# 261              519.6        3280.2           21114.6               14815.4
# 262              173.8        3547.3           23113.7               13949.7
# 263              488.3        4255.8           22292.3               15703.3
# 264              160.1        4603.5           24540.9               14706.2
# 265              467.2        4265.1           21078.5               18037.5
# 266              283.5        3828.6           25198.0               17756.5
# 267              450.0        4911.4           23233.5               21965.1
# 268              209.4        3426.8           28161.7               37021.1
# 269             2483.5        4290.1           26894.1               29622.9
# 270              843.8        3956.3           28594.3               28876.7
# 271                NaN           NaN               NaN                   NaN
#
#      derechos_importacion  ganancias  impuestos_internos  ingresos_capital  \
# 0                     NaN        NaN                 NaN               NaN
# 1                     NaN        NaN                 NaN               NaN
# 2                     NaN        NaN                 NaN               NaN
# 3                     NaN        NaN                 NaN               NaN
# 4                     NaN        NaN                 NaN               NaN
# 5                     NaN        NaN                 NaN               NaN
# 6                     NaN        NaN                 NaN               NaN
# 7                     NaN        NaN                 NaN               NaN
# 8                     NaN        NaN                 NaN               NaN
# 9                     NaN        NaN                 NaN               NaN
# 10                    NaN        NaN                 NaN               NaN
# 11                    NaN        NaN                 NaN               NaN
# 12                    NaN        NaN                 NaN               NaN
# 13                    NaN        NaN                 NaN               NaN
# 14                    NaN        NaN                 NaN               NaN
# 15                    NaN        NaN                 NaN               NaN
# 16                    NaN        NaN                 NaN               NaN
# 17                    NaN        NaN                 NaN               NaN
# 18                    NaN        NaN                 NaN               NaN
# 19                    NaN        NaN                 NaN               NaN
# 20                    NaN        NaN                 NaN               NaN
# 21                    NaN        NaN                 NaN               NaN
# 22                    NaN        NaN                 NaN               NaN
# 23                    NaN        NaN                 NaN               NaN
# 24                    NaN        NaN                 NaN               NaN
# 25                    NaN        NaN                 NaN               NaN
# 26                    NaN        NaN                 NaN               NaN
# 27                    NaN        NaN                 NaN               NaN
# 28                    NaN        NaN                 NaN               NaN
# 29                    NaN        NaN                 NaN               NaN
# ..                    ...        ...                 ...               ...
# 242                5292.0    16294.3              2501.0               3.1
# 243                4683.6    14551.7              2821.2               1.5
# 244                4922.0    25683.1              2600.6              16.4
# 245                5519.3    29958.9              2644.9             241.1
# 246                5551.3    25372.6              2729.7               2.9
# 247                6779.7    23787.4              2948.2               9.5
# 248                6494.6    25381.7              3098.9             401.8
# 249                6523.7    23973.2              3209.6            1008.9
# 250                6595.7    23292.5              3273.5             574.4
# 251                4598.0    26877.2              3024.4             465.1
# 252                7780.9    19290.7              3481.0              49.8
# 253                6272.5    17608.0              2927.1              43.8
# 254                7078.7    18200.1              2813.2             331.5
# 255                7668.8    15636.9              3142.1             290.1
# 256                8536.5    29468.6              3227.0            1195.8
# 257                8623.1    36345.2              2687.1             192.3
# 258                9599.0    23148.6              2811.7            4931.0
# 259               10205.0    26648.1              2788.3            1102.8
# 260               10286.1    22869.5              2737.9             642.9
# 261               11381.7    24311.5              3307.4            2877.3
# 262                8431.9    25194.5              3122.4             319.2
# 263                8183.5    28004.1              3989.7             225.7
# 264                9260.1    18453.4              4057.1             355.9
# 265                7762.5    18327.2              3717.8             624.8
# 266                8972.1    18783.9              3372.0             249.5
# 267                7931.6    23869.6              3501.7             624.2
# 268               11368.7    45011.4              3357.7             195.2
# 269                9739.5    47682.4              3410.4           64571.5
# 270               11032.6    33163.5              3514.7           12392.5
# 271                   NaN        NaN                 NaN               NaN
#
#      iva_neto_reintegros  resto_rentas_propiedad  resto_tributarios  \
# 0                    NaN                     NaN                NaN
# 1                    NaN                     NaN                NaN
# 2                    NaN                     NaN                NaN
# 3                    NaN                     NaN                NaN
# 4                    NaN                     NaN                NaN
# 5                    NaN                     NaN                NaN
# 6                    NaN                     NaN                NaN
# 7                    NaN                     NaN                NaN
# 8                    NaN                     NaN                NaN
# 9                    NaN                     NaN                NaN
# 10                   NaN                     NaN                NaN
# 11                   NaN                     NaN                NaN
# 12                   NaN                     NaN                NaN
# 13                   NaN                     NaN                NaN
# 14                   NaN                     NaN                NaN
# 15                   NaN                     NaN                NaN
# 16                   NaN                     NaN                NaN
# 17                   NaN                     NaN                NaN
# 18                   NaN                     NaN                NaN
# 19                   NaN                     NaN                NaN
# 20                   NaN                     NaN                NaN
# 21                   NaN                     NaN                NaN
# 22                   NaN                     NaN                NaN
# 23                   NaN                     NaN                NaN
# 24                   NaN                     NaN                NaN
# 25                   NaN                     NaN                NaN
# 26                   NaN                     NaN                NaN
# 27                   NaN                     NaN                NaN
# 28                   NaN                     NaN                NaN
# 29                   NaN                     NaN                NaN
# ..                   ...                     ...                ...
# 242              23844.3                  4297.1            26515.9
# 243              26919.1                  2087.8            18620.1
# 244              26732.1                  3049.9             8884.1
# 245              28188.4                  2741.7             8389.4
# 246              29200.1                  2160.3             8204.4
# 247              31746.7                  4029.5             8160.8
# 248              31390.1                  2457.0             8025.5
# 249              31758.9                  2504.8             8032.7
# 250              33841.7                  4939.7             8864.5
# 251              34370.0                  8669.6             9527.8
# 252              38433.3                  1508.0             7515.7
# 253              35210.8                  2043.8             8163.3
# 254              36396.5                 22785.0             8085.1
# 255              36042.4                 12618.7             9059.0
# 256              39946.4                  6093.1             8917.1
# 257              41830.7                  4703.1            10407.9
# 258              40591.7                  7312.4             9324.5
# 259              44103.9                 11878.9            10092.5
# 260              46516.1                 10349.7             9908.0
# 261              50177.1                 12324.3            11003.5
# 262              43505.0                 11344.5            10378.0
# 263              42823.9                 14255.0            10594.2
# 264              56602.1                  4354.5            10791.4
# 265              49920.9                 10209.5            10445.6
# 266              48942.1                 18969.0            10863.8
# 267              46906.2                  6263.3            12560.6
# 268              60787.8                  5829.1            15008.6
# 269              54551.3                  3622.9            17075.4
# 270              59295.4                  7450.6            16877.9
# 271                  NaN                     NaN                NaN
#
#      resto_rentas_propiedad.1
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN
# 28                        NaN
# 29                        NaN
# ..                        ...
# 242                    4297.1
# 243                    2087.8
# 244                    3049.9
# 245                    2741.7
# 246                    2160.3
# 247                    4029.5
# 248                    2457.0
# 249                    2504.8
# 250                    4939.7
# 251                    8669.6
# 252                    1508.0
# 253                    2043.8
# 254                   22785.0
# 255                   12618.7
# 256                    6093.1
# 257                    4703.1
# 258                    7312.4
# 259                   11878.9
# 260                   10349.7
# 261                   12324.3
# 262                   11344.5
# 263                   14255.0
# 264                    4354.5
# 265                   10209.5
# 266                   18969.0
# 267                    6263.3
# 268                    5829.1
# 269                    3622.9
# 270                    7450.6
# 271                       NaN
#
# [272 rows x 15 columns]

# %% [markdown]
# 2) Convertimos en "datetime" al campo "indice_de_tiempo".

# %%
#Transformo en fecha el campo índice_tiempo
reca_total["indice_tiempo"] = pd.to_datetime(reca_total["indice_tiempo"])
#Tranformo el campo índice_tiempo en el índice del dataframe

# %% [markdown]
# 3) Tomamos los datos desde 2016.

# %%
#reca_total = reca_total.set_index("indice_tiempo")
reca_total=reca_total[reca_total.indice_tiempo>="2016-01-01"]
reca_total.head()
# Out:
#     indice_tiempo  total_recaudacion  aportes_contribuciones_seguridad_social  \
# 228    2016-01-01      162654.151319                                  50824.0
# 229    2016-02-01      134803.277269                                  37246.3
# 230    2016-03-01      137762.369260                                  37906.8
# 231    2016-04-01      150809.702557                                  42730.7
# 232    2016-05-01      170344.610158                                  42640.1
#
#      bienes_personales  combustibles  debitos_creditos  derechos_exportacion  \
# 228              161.6        1115.1            7764.7                5102.6
# 229              559.4        1960.3            7232.6                3511.5
# 230              160.1        1854.7            7890.7                6749.9
# 231              380.9        1893.8            8815.4               12214.0
# 232             2287.6        1904.8            8918.6                8199.3
#
#      derechos_importacion  ganancias  impuestos_internos  ingresos_capital  \
# 228                3846.0    20340.3              1569.5               2.8
# 229                3678.7    15531.2              1692.4               5.1
# 230                4679.5    12671.4              1590.1              16.9
# 231                4630.4    11897.8              1683.0               2.7
# 232                4518.7    25960.7              2108.2              85.8
#
#      iva_neto_reintegros  resto_rentas_propiedad  resto_tributarios  \
# 228             20467.30                   270.3            5140.20
# 229             20109.65                   234.1            4319.14
# 230             21943.30                   480.9            4286.80
# 231             22904.30                   493.3            4854.40
# 232             26738.40                  1007.5            5856.20
#
#      resto_rentas_propiedad.1
# 228                     270.3
# 229                     234.1
# 230                     480.9
# 231                     493.3
# 232                    1007.5

# %% [markdown]
# 4) Corroboro que todos los campos tengan la misma cantidad de registros no nulos con los que trabajar y me aseguro de contar con un campo a utilizar como índice temporal.

# %%
reca_total = reca_total.set_index("indice_tiempo")
reca_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 44 entries, 2016-01-01 to 2019-08-01
# Data columns (total 14 columns):
# total_recaudacion                          44 non-null float64
# aportes_contribuciones_seguridad_social    43 non-null float64
# bienes_personales                          43 non-null float64
# combustibles                               43 non-null float64
# debitos_creditos                           43 non-null float64
# derechos_exportacion                       43 non-null float64
# derechos_importacion                       43 non-null float64
# ganancias                                  43 non-null float64
# impuestos_internos                         43 non-null float64
# ingresos_capital                           43 non-null float64
# iva_neto_reintegros                        43 non-null float64
# resto_rentas_propiedad                     43 non-null float64
# resto_tributarios                          43 non-null float64
# resto_rentas_propiedad.1                   43 non-null float64
# dtypes: float64(14)
# memory usage: 5.2 KB

# %%
reca_total.columns.tolist()
#al transformar "indice_tiempo" en el índice de la tabla ya no la reconoce como columna sino como índice.
# Out:
# ['total_recaudacion',
#  'aportes_contribuciones_seguridad_social',
#  'bienes_personales',
#  'combustibles',
#  'debitos_creditos',
#  'derechos_exportacion',
#  'derechos_importacion',
#  'ganancias',
#  'impuestos_internos',
#  'ingresos_capital',
#  'iva_neto_reintegros',
#  'resto_rentas_propiedad',
#  'resto_tributarios',
#  'resto_rentas_propiedad.1']

# %% [markdown]
# 4)  Si no lo hice antes, planteo el tipo de agrupación de los datos para lograr una mejor visualización.
# En nuestro ejemplo al querer mostrar los datos de forma trimestral, generamos un campo con el Año-trimestre de cada registro y luego lo agrupamos.

# %%
reca_total["anio_trim"]= reca_total.index.year.astype(str) + " - " +reca_total.index.quarter.astype(str)+ "T" 
reca_total.head()

# mes = reca_total["indice_tiempo"].dt.month
# trim= {1:"1T", 2:"1T", 3:"1T", 4:"2T", 5:"2T", 6:"2T", 7:"3T", 8:"3T", 9:"3T", 10:"4T", 11:"4T", 12:"4T"}

# reca_total["trim"]= mes.apply(lambda x: trim[x])
# reca_total["anio"]= reca_total["indice_tiempo"].dt.year
# reca_total["trim_anio"]= reca_total["anio"].astype(str) + "-" + reca_total["trim"].astype(str)

# del reca_total["trim"]
# del reca_total["anio"]

#reca_total = reca_total.set_index("anio_trim")  -VER SI ES NECESARIO CONVERTIRLO EN ÍNDICE O USARLO SÓLO PARA LOS GRÁFICOS.
# Out:
#                total_recaudacion  aportes_contribuciones_seguridad_social  \
# indice_tiempo
# 2016-01-01         162654.151319                                  50824.0
# 2016-02-01         134803.277269                                  37246.3
# 2016-03-01         137762.369260                                  37906.8
# 2016-04-01         150809.702557                                  42730.7
# 2016-05-01         170344.610158                                  42640.1
#
#                bienes_personales  combustibles  debitos_creditos  \
# indice_tiempo
# 2016-01-01                 161.6        1115.1            7764.7
# 2016-02-01                 559.4        1960.3            7232.6
# 2016-03-01                 160.1        1854.7            7890.7
# 2016-04-01                 380.9        1893.8            8815.4
# 2016-05-01                2287.6        1904.8            8918.6
#
#                derechos_exportacion  derechos_importacion  ganancias  \
# indice_tiempo
# 2016-01-01                   5102.6                3846.0    20340.3
# 2016-02-01                   3511.5                3678.7    15531.2
# 2016-03-01                   6749.9                4679.5    12671.4
# 2016-04-01                  12214.0                4630.4    11897.8
# 2016-05-01                   8199.3                4518.7    25960.7
#
#                impuestos_internos  ingresos_capital  iva_neto_reintegros  \
# indice_tiempo
# 2016-01-01                 1569.5               2.8             20467.30
# 2016-02-01                 1692.4               5.1             20109.65
# 2016-03-01                 1590.1              16.9             21943.30
# 2016-04-01                 1683.0               2.7             22904.30
# 2016-05-01                 2108.2              85.8             26738.40
#
#                resto_rentas_propiedad  resto_tributarios  \
# indice_tiempo
# 2016-01-01                      270.3            5140.20
# 2016-02-01                      234.1            4319.14
# 2016-03-01                      480.9            4286.80
# 2016-04-01                      493.3            4854.40
# 2016-05-01                     1007.5            5856.20
#
#                resto_rentas_propiedad.1  anio_trim
# indice_tiempo
# 2016-01-01                        270.3  2016 - 1T
# 2016-02-01                        234.1  2016 - 1T
# 2016-03-01                        480.9  2016 - 1T
# 2016-04-01                        493.3  2016 - 2T
# 2016-05-01                       1007.5  2016 - 2T

# %%
reca_total_trim= reca_total.groupby("anio_trim").sum()
reca_total_trim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 2016 - 1T to 2019 - 3T
# Data columns (total 14 columns):
# total_recaudacion                          15 non-null float64
# aportes_contribuciones_seguridad_social    15 non-null float64
# bienes_personales                          15 non-null float64
# combustibles                               15 non-null float64
# debitos_creditos                           15 non-null float64
# derechos_exportacion                       15 non-null float64
# derechos_importacion                       15 non-null float64
# ganancias                                  15 non-null float64
# impuestos_internos                         15 non-null float64
# ingresos_capital                           15 non-null float64
# iva_neto_reintegros                        15 non-null float64
# resto_rentas_propiedad                     15 non-null float64
# resto_tributarios                          15 non-null float64
# resto_rentas_propiedad.1                   15 non-null float64
# dtypes: float64(14)
# memory usage: 1.8+ KB

# %%
reca_total_trim[:3]
# Out:
#            total_recaudacion  aportes_contribuciones_seguridad_social  \
# anio_trim
# 2016 - 1T      435219.797848                            125977.100000
# 2016 - 2T      495751.044070                            128400.300000
# 2016 - 3T      514171.757950                            151921.377418
#
#            bienes_personales  combustibles  debitos_creditos  \
# anio_trim
# 2016 - 1T              881.1     4930.1000           22888.0
# 2016 - 2T             3974.0     6488.9000           26996.9
# 2016 - 3T             1599.7     8066.4482           29238.8
#
#            derechos_exportacion  derechos_importacion   ganancias  \
# anio_trim
# 2016 - 1T               15364.0               12204.2  48542.9000
# 2016 - 2T               25417.3               13761.4  63132.0000
# 2016 - 3T               17412.7               15018.5  53522.5361
#
#            impuestos_internos  ingresos_capital  iva_neto_reintegros  \
# anio_trim
# 2016 - 1T            4852.000              24.8           62520.2500
# 2016 - 2T            5882.000             154.5           71860.5000
# 2016 - 3T            6983.671              35.0           71745.5882
#
#            resto_rentas_propiedad  resto_tributarios  resto_rentas_propiedad.1
# anio_trim
# 2016 - 1T                   985.3         13746.1400                     985.3
# 2016 - 2T                  1941.2         17911.4000                    1941.2
# 2016 - 3T                  4281.4         21149.5744                    4281.4

# %%
reca_total_porc= (reca_total_trim.T/reca_total_trim.total_recaudacion).T
reca_total_porc.T.sum()
# Out:
# anio_trim
# 2016 - 1T    1.721247
# 2016 - 2T    1.742029
# 2016 - 3T    1.749276
# 2016 - 4T    1.783230
# 2017 - 1T    1.769175
# 2017 - 2T    1.746844
# 2017 - 3T    1.737857
# 2017 - 4T    1.757357
# 2018 - 1T    1.763817
# 2018 - 2T    1.737994
# 2018 - 3T    1.759165
# 2018 - 4T    1.769176
# 2019 - 1T    1.753748
# 2019 - 2T    1.740213
# 2019 - 3T    1.376329
# dtype: float64

# %%
resto_porc= reca_total_porc.T.sum()-1
resto_porc
# Out:
# anio_trim
# 2016 - 1T    0.721247
# 2016 - 2T    0.742029
# 2016 - 3T    0.749276
# 2016 - 4T    0.783230
# 2017 - 1T    0.769175
# 2017 - 2T    0.746844
# 2017 - 3T    0.737857
# 2017 - 4T    0.757357
# 2018 - 1T    0.763817
# 2018 - 2T    0.737994
# 2018 - 3T    0.759165
# 2018 - 4T    0.769176
# 2019 - 1T    0.753748
# 2019 - 2T    0.740213
# 2019 - 3T    0.376329
# dtype: float64

# %%
reca_total_trim["Otros conceptos"]= reca_total_trim.total_recaudacion*(1-resto_porc)
reca_total_trim[:4]
reca_total_porc= (reca_total_trim.T/reca_total_trim.total_recaudacion).T
reca_total_porc.T.sum()-1
# Out:
# anio_trim
# 2016 - 1T    1.0
# 2016 - 2T    1.0
# 2016 - 3T    1.0
# 2016 - 4T    1.0
# 2017 - 1T    1.0
# 2017 - 2T    1.0
# 2017 - 3T    1.0
# 2017 - 4T    1.0
# 2018 - 1T    1.0
# 2018 - 2T    1.0
# 2018 - 3T    1.0
# 2018 - 4T    1.0
# 2019 - 1T    1.0
# 2019 - 2T    1.0
# 2019 - 3T    1.0
# dtype: float64

# %%
reca_total_porc=reca_total_porc*100

# %%
del reca_total_porc["total_recaudacion"]

# %%
#DEBERÍA REHUBICAR LAS ETIQUETAS FUERA DEL ÁREA DEL GRÁFICO
reca_total_porc.plot(kind="bar", stacked=True, 
                     title="Evolución trimestral del aporte por concepto a la Recaudación Total", figsize=(20,10))

plt.ylabel("Aporte en % por concepto")
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
Var_porc_trim= reca_total_trim.pct_change(1)
Var_porc_trim.plot(figsize= (20,10))
plt.xlabel= ("anio_trim")
plt.legend(loc="upper left")

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 10))

reca_total_trim.plot.scatter("iva_neto_reintegros", "total_recaudacion", ax=axes[0,0], title="RT vs. IVA")
reca_total_trim.plot.scatter("ganancias", "total_recaudacion", ax=axes[0,1], title="RT vs. Ganancias")
reca_total_trim.plot.scatter("derechos_exportacion", "total_recaudacion", ax=axes[0,2], title="RT vs. Expo ")

reca_total_trim.plot.scatter("debitos_creditos", "total_recaudacion", ax=axes[1,0], title="VAR vs. Debitos y Créditos")
reca_total_trim.plot.scatter("ingresos_capital", "total_recaudacion", ax=axes[1,1], title="VAR vs. Capital")
reca_total_trim.plot.scatter("resto_rentas_propiedad.1", "total_recaudacion", ax=axes[1,2], title="RT vs. Rentas de la Propiedad")

# elimina los labels de los ejes para que se vea mejor
for row in axes:
    for ax in row:
        pass
        ax.set_xlabel("")
        ax.set_ylabel("")

# %%
reca_total_trim.corr()
# Out:
#                                          total_recaudacion  \
# total_recaudacion                                 1.000000
# aportes_contribuciones_seguridad_social           0.959317
# bienes_personales                                 0.114458
# combustibles                                      0.798683
# debitos_creditos                                  0.970714
# derechos_exportacion                              0.775795
# derechos_importacion                              0.917809
# ganancias                                         0.763660
# impuestos_internos                                0.812342
# ingresos_capital                                  0.632706
# iva_neto_reintegros                               0.972359
# resto_rentas_propiedad                            0.708910
# resto_tributarios                                 0.108724
# resto_rentas_propiedad.1                          0.708910
# Otros conceptos                                   0.984097
#
#                                          aportes_contribuciones_seguridad_social  \
# total_recaudacion                                                       0.959317
# aportes_contribuciones_seguridad_social                                 1.000000
# bienes_personales                                                       0.010722
# combustibles                                                            0.801107
# debitos_creditos                                                        0.955884
# derechos_exportacion                                                    0.648052
# derechos_importacion                                                    0.913457
# ganancias                                                               0.625572
# impuestos_internos                                                      0.857666
# ingresos_capital                                                        0.478954
# iva_neto_reintegros                                                     0.975159
# resto_rentas_propiedad                                                  0.797282
# resto_tributarios                                                       0.000961
# resto_rentas_propiedad.1                                                0.797282
# Otros conceptos                                                         0.937001
#
#                                          bienes_personales  combustibles  \
# total_recaudacion                                 0.114458      0.798683
# aportes_contribuciones_seguridad_social           0.010722      0.801107
# bienes_personales                                 1.000000      0.266313
# combustibles                                      0.266313      1.000000
# debitos_creditos                                  0.001793      0.743952
# derechos_exportacion                              0.230591      0.427032
# derechos_importacion                              0.044454      0.788751
# ganancias                                         0.571861      0.733625
# impuestos_internos                                0.076732      0.855711
# ingresos_capital                                  0.299532      0.265793
# iva_neto_reintegros                               0.064232      0.798608
# resto_rentas_propiedad                           -0.313996      0.598423
# resto_tributarios                                -0.130882      0.113632
# resto_rentas_propiedad.1                         -0.313996      0.598423
# Otros conceptos                                   0.201649      0.787080
#
#                                          debitos_creditos  \
# total_recaudacion                                0.970714
# aportes_contribuciones_seguridad_social          0.955884
# bienes_personales                                0.001793
# combustibles                                     0.743952
# debitos_creditos                                 1.000000
# derechos_exportacion                             0.736752
# derechos_importacion                             0.954914
# ganancias                                        0.651621
# impuestos_internos                               0.762549
# ingresos_capital                                 0.537053
# iva_neto_reintegros                              0.985086
# resto_rentas_propiedad                           0.820513
# resto_tributarios                               -0.022609
# resto_rentas_propiedad.1                         0.820513
# Otros conceptos                                  0.949223
#
#                                          derechos_exportacion  \
# total_recaudacion                                    0.775795
# aportes_contribuciones_seguridad_social              0.648052
# bienes_personales                                    0.230591
# combustibles                                         0.427032
# debitos_creditos                                     0.736752
# derechos_exportacion                                 1.000000
# derechos_importacion                                 0.576275
# ganancias                                            0.629831
# impuestos_internos                                   0.387846
# ingresos_capital                                     0.844489
# iva_neto_reintegros                                  0.704577
# resto_rentas_propiedad                               0.308016
# resto_tributarios                                   -0.012323
# resto_rentas_propiedad.1                             0.308016
# Otros conceptos                                      0.806433
#
#                                          derechos_importacion  ganancias  \
# total_recaudacion                                    0.917809   0.763660
# aportes_contribuciones_seguridad_social              0.913457   0.625572
# bienes_personales                                    0.044454   0.571861
# combustibles                                         0.788751   0.733625
# debitos_creditos                                     0.954914   0.651621
# derechos_exportacion                                 0.576275   0.629831
# derechos_importacion                                 1.000000   0.675728
# ganancias                                            0.675728   1.000000
# impuestos_internos                                   0.759466   0.625964
# ingresos_capital                                     0.414233   0.676723
# iva_neto_reintegros                                  0.952969   0.677374
# resto_rentas_propiedad                               0.837763   0.280377
# resto_tributarios                                   -0.049243   0.086118
# resto_rentas_propiedad.1                             0.837763   0.280377
# Otros conceptos                                      0.892945   0.804694
#
#                                          impuestos_internos  ingresos_capital  \
# total_recaudacion                                  0.812342          0.632706
# aportes_contribuciones_seguridad_social            0.857666          0.478954
# bienes_personales                                  0.076732          0.299532
# combustibles                                       0.855711          0.265793
# debitos_creditos                                   0.762549          0.537053
# derechos_exportacion                               0.387846          0.844489
# derechos_importacion                               0.759466          0.414233
# ganancias                                          0.625964          0.676723
# impuestos_internos                                 1.000000          0.198462
# ingresos_capital                                   0.198462          1.000000
# iva_neto_reintegros                                0.818550          0.501904
# resto_rentas_propiedad                             0.719767          0.044656
# resto_tributarios                                  0.195436          0.055003
# resto_rentas_propiedad.1                           0.719767          0.044656
# Otros conceptos                                    0.761242          0.680668
#
#                                          iva_neto_reintegros  \
# total_recaudacion                                   0.972359
# aportes_contribuciones_seguridad_social             0.975159
# bienes_personales                                   0.064232
# combustibles                                        0.798608
# debitos_creditos                                    0.985086
# derechos_exportacion                                0.704577
# derechos_importacion                                0.952969
# ganancias                                           0.677374
# impuestos_internos                                  0.818550
# ingresos_capital                                    0.501904
# iva_neto_reintegros                                 1.000000
# resto_rentas_propiedad                              0.812265
# resto_tributarios                                  -0.045529
# resto_rentas_propiedad.1                            0.812265
# Otros conceptos                                     0.955443
#
#                                          resto_rentas_propiedad  \
# total_recaudacion                                      0.708910
# aportes_contribuciones_seguridad_social                0.797282
# bienes_personales                                     -0.313996
# combustibles                                           0.598423
# debitos_creditos                                       0.820513
# derechos_exportacion                                   0.308016
# derechos_importacion                                   0.837763
# ganancias                                              0.280377
# impuestos_internos                                     0.719767
# ingresos_capital                                       0.044656
# iva_neto_reintegros                                    0.812265
# resto_rentas_propiedad                                 1.000000
# resto_tributarios                                     -0.127534
# resto_rentas_propiedad.1                               1.000000
# Otros conceptos                                        0.631798
#
#                                          resto_tributarios  \
# total_recaudacion                                 0.108724
# aportes_contribuciones_seguridad_social           0.000961
# bienes_personales                                -0.130882
# combustibles                                      0.113632
# debitos_creditos                                 -0.022609
# derechos_exportacion                             -0.012323
# derechos_importacion                             -0.049243
# ganancias                                         0.086118
# impuestos_internos                                0.195436
# ingresos_capital                                  0.055003
# iva_neto_reintegros                              -0.045529
# resto_rentas_propiedad                           -0.127534
# resto_tributarios                                 1.000000
# resto_rentas_propiedad.1                         -0.127534
# Otros conceptos                                   0.012030
#
#                                          resto_rentas_propiedad.1  \
# total_recaudacion                                        0.708910
# aportes_contribuciones_seguridad_social                  0.797282
# bienes_personales                                       -0.313996
# combustibles                                             0.598423
# debitos_creditos                                         0.820513
# derechos_exportacion                                     0.308016
# derechos_importacion                                     0.837763
# ganancias                                                0.280377
# impuestos_internos                                       0.719767
# ingresos_capital                                         0.044656
# iva_neto_reintegros                                      0.812265
# resto_rentas_propiedad                                   1.000000
# resto_tributarios                                       -0.127534
# resto_rentas_propiedad.1                                 1.000000
# Otros conceptos                                          0.631798
#
#                                          Otros conceptos
# total_recaudacion                               0.984097
# aportes_contribuciones_seguridad_social         0.937001
# bienes_personales                               0.201649
# combustibles                                    0.787080
# debitos_creditos                                0.949223
# derechos_exportacion                            0.806433
# derechos_importacion                            0.892945
# ganancias                                       0.804694
# impuestos_internos                              0.761242
# ingresos_capital                                0.680668
# iva_neto_reintegros                             0.955443
# resto_rentas_propiedad                          0.631798
# resto_tributarios                               0.012030
# resto_rentas_propiedad.1                        0.631798
# Otros conceptos                                 1.000000
