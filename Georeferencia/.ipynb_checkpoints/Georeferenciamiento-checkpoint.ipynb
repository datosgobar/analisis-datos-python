# %% [markdown]
# # Datos geográficos

# %%
import urllib
import json
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point
import fiona

# %% [markdown]
# Los datos georreferenciados representan ubicaciones exactas sobre la superficie terrestre. Sin embargo, es todo un reto representar en forma precisa una posición en la Tierra cuando ésta tiene una forma irregular. Esto se termina relacionando con el problema de cómo mostrar sobre superficies planas rasgos geográficos que pertenecen a una superficie tridimensional esférica.
# Es por ésto que se desarrollan los Sistemas de coordenadas de referencia (CRS -en inglés-), y de proyecciones cartográficas.
#
# * Los CRS son un sistema de números que definen ubicaciones sobre la superficie de la Tierra; funcionan como direcciones. (Ej: el CRS que usa latitud y longitud para definir posiciones en los ejes norte-sur y este-oeste)
#
# * Las proyecciones cartográficas son instrucciones para traducir a un plano la disposición de puntos ubicados en la esfera terrestre. Como en toda traducción, hay algo que se pierde en el proceso.
#
# Es por éste motivo que existen distintas proyecciones de la Tierra, cada una pensada para minimizar alguno de los tipos de distorsión, o para encontrar una solución de compromiso que los balancée.
#
# La proyección más utilizada en la actualidad es la "Mercator", ésta se diseñó originalmente para asistir la navegación marítima. Su fortaleza es que no distorsiona las direcciones, por lo que permite fijar el rumbo de navegación consultando el mapa. Su principal problema es que produce una distorsión notable en las áreas cercanas a los polos.

# %% [markdown]
# ## Formatos de archivos
#
# El formato más común es el denominado **“shapefile”**. Éste formato guarda la información en varios archivos distintos, generalmente combinados en un archivo .zip para su distribución.
#
# Uno de los inconvenientes que puede tener éste tipo de formato además de que ser de archivo múltiple es que los nombres de las variables dentro del shapefile deben tener 10 caracteres o menos, lo que puede causar abreviaturas ininteligibles.
# Es por ello que los archivos en formatos “GeoJSON” vienen a corregir éstos inconvenientes.

# %% [markdown]
# **¿Cómo leemos los diferentes archivos para poder trabajar con datos georeferenciados entonces?**
#
# * **Archivos del tipo GeoJson**

# %% [markdown]
# Para poder disponer de un GeoDataframe en formato geojson y hacerlo a partir de un url, debo primero importar la líbreria "fiona" y dsps usar la función gpd.read_file()

# %%
url = "https://apis.datos.gob.ar/georef/api/provincias?formato=geojson"
provincias_geojson = gpd.read_file(url)
provincias_geojson.head()
# Out:
#    id      nombre                                      geometry
# 0  54    Misiones   POINT (-54.6516966230371 -26.8753965086829)
# 1  74    San Luis   POINT (-66.0281298195836 -33.7577257449137)
# 2  70    San Juan   POINT (-68.8894908486844 -30.8653679979618)
# 3  30  Entre Ríos   POINT (-59.2014475514635 -32.0588735436448)
# 4  78  Santa Cruz  POINT (-69.95576216719731 -48.8154851827063)

# %% [markdown]
# Dado que los datos georeferenciados de provincias en formato geojson son sólo puntos, intentamos leer el que provee en formato shapefile.

# %% [markdown]
# * **Archivos del tipo shp**

# %% [markdown]
# Desde la API Georef provista por datos.gob.ar es posible acceder al formato shapefile (https://apis.datos.gob.ar/georef/api/provincias?formato=shp").
# Como puede suceder que utilizando el mismo método de lectura que para el archivo geojson, demoremos mucho en abrilo, podemos descargarnos el archivo, descomprimirlo y guardar todos los archivos en la misma carpeta del notebook para después llamar a la ruta en lugar de la url.

# %%
url = "https://apis.datos.gob.ar/georef/api/provincias?formato=shp"
path= "./datos/provincias/provincias.shp"
provincias_shp = gpd.read_file(url)
provincias_shp.head()
# Out:
#            centr_lon  id          centr_lat      nombre  \
# 0  -54.6516966230371  54  -26.8753965086829    Misiones
# 1  -66.0281298195836  74  -33.7577257449137    San Luis
# 2  -68.8894908486844  70  -30.8653679979618    San Juan
# 3  -59.2014475514635  30  -32.0588735436448  Entre Ríos
# 4  -69.9557621671973  78  -48.8154851827063  Santa Cruz
#
#                                             geometry
# 0  (POLYGON ((-54.109057346 -25.539824102, -54.11...
# 1  POLYGON ((-67.055470113 -31.856052636, -67.049...
# 2  POLYGON ((-67.32964173800001 -32.358826402, -6...
# 3  POLYGON ((-58.581376706 -30.160100982, -58.581...
# 4  (POLYGON ((-71.54708990899999 -45.999754002, -...

# %% [markdown]
# Si quisieramos traer únicamente las provincias que en sus nombres comienzan con San, debería escribir:

# %%
url = "https://apis.datos.gob.ar/georef/api/provincias?&nombre=san&formato=shp"
provincias_san_shp = gpd.read_file(url)
provincias_san_shp.head()
# Out:
#            centr_lon  id          centr_lat    nombre  \
# 0  -66.0281298195836  74  -33.7577257449137  San Luis
# 1  -68.8894908486844  70  -30.8653679979618  San Juan
#
#                                             geometry
# 0  POLYGON ((-67.055470113 -31.856052636, -67.049...
# 1  POLYGON ((-67.32964173800001 -32.358826402, -6...

# %% [markdown]
# #### Algunas funciones de la librería Geopandas para datos georeferenciados

# %% [markdown]
# * Selección de datos

# %% [markdown]
# Una forma de seleccionar los datos del GeoDataframe, además de las funciones ".loc" y ".iloc" (las que ya disponíamos usando Pandas), se puede utilizar ".cx" donde se pueden seleccionar las provincias que intersecan el cuadro que delimitan los parámetros de la función, donde el primero refiere a las coordenadas de longitud (abcisas) y el segundo a las coordenadas de latitud (ordenadas).

# %%
provincias_shp.cx[-70:,:-30].plot()

# %%
#Si quisieramos convertir ésta geoserie en formato shape, el comando es el siguiente:
provincias_geojson.to_file("provincia_centroide.shp")
# Para saber en que otros formatos podríamos guardar la info, escribir el siguiente comando
#fiona.supported_drivers
provincias_centroide_shp=gpd.read_file("./provincia_centroide.shp")
provincias_centroide_shp.head()
# Out:
#    id      nombre                                      geometry
# 0  54    Misiones   POINT (-54.6516966230371 -26.8753965086829)
# 1  74    San Luis   POINT (-66.0281298195836 -33.7577257449137)
# 2  70    San Juan   POINT (-68.8894908486844 -30.8653679979618)
# 3  30  Entre Ríos   POINT (-59.2014475514635 -32.0588735436448)
# 4  78  Santa Cruz  POINT (-69.95576216719731 -48.8154851827063)

# %% [markdown]
# * Chequeamos y modificamos la Proyección de los datos

# %%
# Consultamos la proyección en la que están dispuestos los datos
provincias_shp.crs
# Out:
# {'init': 'epsg:4326'}

# %%
provincias_shp.plot()
plt.xlim(-75, -50)
plt.ylim(-60, -20)
plt.title("Argentina - (WGS84 Latitud / Longitud)");

# %%
#Vemos que la proyección CRS de latitud-longitud utilizada es la "WGS84"
#Si quisieramos cambiarla a por ejemplo la proyección "Mercator", deberíamos:
provincias_m= provincias_shp.to_crs({'init': 'epsg:3395'})
provincias_m.crs
# Out:
# {'init': 'epsg:3395'}

# %%
provincias_m.plot()
plt.xlim(-8189395.26639646, -5970884.65399676)
plt.ylim(-7538479.3745755 , -2469419.68821978)
plt.title("Argentina - (Mercator)");

# %% [markdown]
# * **Manipulaciones geométricas**

# %%
#para chequear el tipo de Objeto gráfico, uso la función ".geom_type"
provincias_shp[provincias_shp.index==23].geom_type
# Out:
# 23    MultiPolygon
# dtype: object

# %%
#Si quisieramos representar sólo los contornos de las provincias utilizamos la función .boundary
provincias_shp.boundary.plot()

# %%
provincias_shp.geometry[3]

# %%
provincias_shp.convex_hull[3]

# %%
provincias_shp.simplify(2, preserve_topology = True).plot()

# %%
provincias_shp.centroid.distance(provincias_shp.centroid[0])
# Out:
# 0      0.000000
# 1     13.296228
# 2     14.786300
# 3      6.897004
# 4     26.750363
# 5     18.473456
# 6     21.876348
# 7     10.557958
# 8     15.944176
# 9     12.841344
# 10    12.304604
# 11    14.890261
# 12     8.648384
# 13     3.677682
# 14     7.372055
# 15    10.713306
# 16    19.433771
# 17    10.484224
# 18     6.133655
# 19     5.639888
# 20    11.667441
# 21     8.619122
# 22    11.443974
# 23    55.783247
# dtype: float64

# %% [markdown]
# ### Convertir un Dataframe en un Geodataframe

# %%
#Para crear las coordenadas de algún dataset que contenga direcciones que permitan georeferenciarse
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
dataset = pd.read_csv("https://apis.datos.gob.ar/georef/api/provincias?formato=csv")
dataset.head()
# Out:
#    provincia_id provincia_nombre  provincia_centroide_lat  \
# 0            54         Misiones               -26.875397
# 1            74         San Luis               -33.757726
# 2            70         San Juan               -30.865368
# 3            30       Entre Ríos               -32.058874
# 4            78       Santa Cruz               -48.815485
#
#    provincia_centroide_lon
# 0               -54.651697
# 1               -66.028130
# 2               -68.889491
# 3               -59.201448
# 4               -69.955762

# %%
dataset["coordenadas"]=list(zip(dataset.provincia_centroide_lon, dataset.provincia_centroide_lat))
dataset['coordenadas'] = dataset['coordenadas'].apply(Point)

# %%
prov_punto = gpd.GeoDataFrame(dataset, geometry='coordenadas')
prov_punto.plot()

# %%
ejes= world[~(world["name"]=="Argentina")].plot(color="c")
provincias_shp.plot(ax=ejes, color="lightgray", figsize=(10,20))
prov_punto.plot(ax=ejes, color="r", markersize=4)
plt.xlim(-75, -48)
plt.ylim(-90, -20);

# %% [markdown]
# ## Mapa de calor

# %% [markdown]
# En éste apartado tomaremos un datasets externo al archivo geojson o shp que contiene las provincias georeferenciadas para poder tomar el dato de interés a representar y mergear con el dato georeferenciado y visualizarlo en el mapa.
#
# Como ejemplo tomaremos un datasets de Seguridad que provee la cantidad de delitos informados al Sistema Nacional de Información Criminal por provincias.

# %% [markdown]
# Acá vemos 2 tipos de errores que pueden surgirnos al trabajar con los datasets de seguridad.
# * El primero corresponde a errores de permisos al servidor que brinda la información
# * El segundo nos dice que no estamos considerando el elemento de separación por columnas.
# Tomando en consideración éstos inconvenientes, lo solucionamos descargando el datasets desde la página de datos.gov.ar, lo agregamos al la carpeta de trabajo del repo y señalamos el elemento de separación.

# %%
df_snic= pd.read_csv("https://estadisticascriminales.minseg.gob.ar/datos/snic-provincias.csv")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-22-3a4c9cc314e5> in <module>
# ----> 1 df_snic= pd.read_csv("https://estadisticascriminales.minseg.gob.ar/datos/snic-provincias.csv")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
df_snic = pd.read_csv("./datos/provincias/snic-provincias.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-23-3c786f43bd65> in <module>
# ----> 1 df_snic = pd.read_csv("./datos/provincias/snic-provincias.csv")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %% [markdown]
# Cómo lo salvamos?
# * descargamos el archivo
# * lo guardamos en la misma ruta del notebook o en una carpeta con nombre "datos" (para ser uniformes con los criterios del armado del repo)
# * lo leemos desde la ruta que hayamos creado y accedemos.

# %%
df_snic = pd.read_csv("datos/provincias/snic-provincias.csv", sep=";", encoding="utf8")
df_snic.head(2)
# Out:
#    anio  provincia_id                 provincia_nombre  codigo_delito_snic_id  \
# 0  2014             2  Ciudad Autsnoma de Buenos Aires                      1
# 1  2014             2  Ciudad Autsnoma de Buenos Aires                      2
#
#                   codigo_delito_snic_nombre  cantidad_hechos  \
# 0                        Homicidios dolosos            185.0
# 1  Homicidios dolosos en grado de tentativa             54.0
#
#    cantidad_victimas
# 0              200.0
# 1               68.0

# %%
provincias_shp.head(2)
# Out:
#            centr_lon  id          centr_lat    nombre  \
# 0  -54.6516966230371  54  -26.8753965086829  Misiones
# 1  -66.0281298195836  74  -33.7577257449137  San Luis
#
#                                             geometry
# 0  (POLYGON ((-54.109057346 -25.539824102, -54.11...
# 1  POLYGON ((-67.055470113 -31.856052636, -67.049...

# %% [markdown]
# Como queremos agregar los datos de homicidio a la estructura de datos georeferenciados y así poder así representarlos en un mapa de calor, debemos dejar uniformes los datos del campo a utilizar para mergear ambos Dataframes. Es por eso que convertimos el campo "provincia_id" a un tipo de datos de 2 dígitos y texto en el archivo de SNIC.

# %%
df_snic = pd.read_csv(
    "datos/provincias/snic-provincias.csv", sep=";", decimal=",",
    converters={
        "provincia_id": lambda x: str(x).zfill(2)
    }
)
df_snic.head()
# Out:
#    anio provincia_id                 provincia_nombre  codigo_delito_snic_id  \
# 0  2014           02  Ciudad Autsnoma de Buenos Aires                      1
# 1  2014           02  Ciudad Autsnoma de Buenos Aires                      2
# 2  2014           02  Ciudad Autsnoma de Buenos Aires                      3
# 3  2014           02  Ciudad Autsnoma de Buenos Aires                      4
# 4  2014           02  Ciudad Autsnoma de Buenos Aires                      5
#
#                   codigo_delito_snic_nombre cantidad_hechos cantidad_victimas
# 0                        Homicidios dolosos             185               200
# 1  Homicidios dolosos en grado de tentativa              54                68
# 2   Homicidios cuposos en siniestros viales              82               102
# 3       Homicidios cuposos por otros hechos              23                24
# 4                          Lesiones dolosas           18679             21175

# %%
len(provincias_shp), len(df_snic)
# Out:
# (24, 3552)

# %%
len(df_snic[df_snic.anio == 2018])
# Out:
# 720

# %%
df_snic[(df_snic.anio == 2018) & (df_snic.codigo_delito_snic_id == 1)].head(2)
# Out:
#       anio provincia_id        provincia_nombre  codigo_delito_snic_id  \
# 2832  2018           02  Ciudad de Buenos Aires                      1
# 2862  2018           06            Buenos Aires                      1
#
#      codigo_delito_snic_nombre cantidad_hechos cantidad_victimas
# 2832        Homicidios dolosos             133               137
# 2862        Homicidios dolosos             951               992

# %%
victimas_homicidios_2018 = df_snic[(df_snic.anio == 2018) & (df_snic.codigo_delito_snic_id == 1)][["provincia_id", "cantidad_victimas"]]

victimas_homicidios_2018["cantidad_victimas"] = victimas_homicidios_2018["cantidad_victimas"].astype(int) 
victimas_homicidios_2018.head(2)
# Out:
#      provincia_id  cantidad_victimas
# 2832           02                137
# 2862           06                992

# %%
provincias_seguridad = provincias_shp.merge(victimas_homicidios_2018, left_on="id", right_on="provincia_id")

# %%
provincias_seguridad.plot(column='cantidad_victimas', cmap=plt.cm.twilight, legend=True)

# %% [markdown]
# ## Normalización direcciones

# %%
import requests as rqs

# %%
direccion = 'Honduras 3755, CABA'
provincia = 'caba'
url_base ='https://apis.datos.gob.ar/georef/api/direcciones?direccion={}&provincia={}'
url_base.format(direccion, provincia)
# Out:
# 'https://apis.datos.gob.ar/georef/api/direcciones?direccion=Honduras 3755, CABA&provincia=caba'

# %%
r = rqs.get(url_base.format(direccion, provincia))
r.json()
# Out:
# {'cantidad': 1,
#  'direcciones': [{'altura': {'unidad': None, 'valor': 3755},
#    'calle': {'categoria': 'AV',
#     'id': '0209801001415',
#     'nombre': 'AV HONDURAS'},
#    'calle_cruce_1': {'categoria': None, 'id': None, 'nombre': None},
#    'calle_cruce_2': {'categoria': None, 'id': None, 'nombre': None},
#    'departamento': {'id': '02098', 'nombre': 'Comuna 14'},
#    'localidad_censal': {'id': '02000010',
#     'nombre': 'Ciudad Autónoma de Buenos Aires'},
#    'nomenclatura': 'AV HONDURAS 3755, Comuna 14, Ciudad Autónoma de Buenos Aires',
#    'piso': None,
#    'provincia': {'id': '02', 'nombre': 'Ciudad Autónoma de Buenos Aires'},
#    'ubicacion': {'lat': -34.59407315430296, 'lon': -58.41550703113384}}],
#  'inicio': 0,
#  'parametros': {'direccion': {'altura': {'unidad': None, 'valor': '3755'},
#    'calles': ['Honduras'],
#    'piso': None,
#    'tipo': 'simple'},
#   'provincia': 'caba'},
#  'total': 1}

# %%
r.json()["parametros"]
# Out:
# {'direccion': {'altura': {'unidad': None, 'valor': '3755'},
#   'calles': ['Honduras'],
#   'piso': None,
#   'tipo': 'simple'},
#  'provincia': 'caba'}

# %%
data = r.json()
data['direcciones'][0]
# Out:
# {'altura': {'unidad': None, 'valor': 3755},
#  'calle': {'categoria': 'AV', 'id': '0209801001415', 'nombre': 'AV HONDURAS'},
#  'calle_cruce_1': {'categoria': None, 'id': None, 'nombre': None},
#  'calle_cruce_2': {'categoria': None, 'id': None, 'nombre': None},
#  'departamento': {'id': '02098', 'nombre': 'Comuna 14'},
#  'localidad_censal': {'id': '02000010',
#   'nombre': 'Ciudad Autónoma de Buenos Aires'},
#  'nomenclatura': 'AV HONDURAS 3755, Comuna 14, Ciudad Autónoma de Buenos Aires',
#  'piso': None,
#  'provincia': {'id': '02', 'nombre': 'Ciudad Autónoma de Buenos Aires'},
#  'ubicacion': {'lat': -34.59407315430296, 'lon': -58.41550703113384}}

# %%
data['direcciones'][0]['ubicacion']
# Out:
# {'lat': -34.59407315430296, 'lon': -58.41550703113384}

# %%
direccion = ['Belgrano 637',
'Balcarce 50',
'Av San Martin 935']

df = pd.DataFrame(data=direccion,columns=['direccion'])
df
# Out:
#            direccion
# 0       Belgrano 637
# 1        Balcarce 50
# 2  Av San Martin 935

# %%
def interpretar_direccion(direccion):
    url_base ='https://apis.datos.gob.ar/georef/api/direcciones?direccion={}'
    r = requests.get(url_base.format(direccion))
    data = r.json()
    ubicacion = data['direcciones'][0]['ubicacion']
    return Point((ubicacion['lat'], ubicacion['lon']))

# %%
df['geometry'] = df["direccion"].apply(interpretar_direccion)
dfs = gpd.GeoDataFrame(df, geometry='geometry')
dfs.plot()

# %%
efectores_salud= pd.read_csv("est_salud.csv")
efectores_salud.head(2)
# Out:
#    establecimiento_id                establecimiento_nombre  localidad_id  \
# 0      10060422200271  HOSPITAL MUNICIPAL DR. PEDRO SOLANET    6042010000
# 1      50060422201241             CENTRO DE SALUD EVA PERON    6042010000
#
#   localidad_nombre  provincia_id provincia_nombre  departamento_id  \
# 0         AYACUCHO             6     BUENOS AIRES               42
# 1         AYACUCHO             6     BUENOS AIRES               42
#
#   departamento_nombre  cod_loc  cod_ent origen_financiamiento  tipologia_id  \
# 0            AYACUCHO       10      0.0             Municipal            10
# 1            AYACUCHO       10      0.0             Municipal            50
#
#   tipologia_sigla                                          tipologia    cp  \
# 0           ESCIG                  Alto riesgo con terapia intensiva  7150
# 1          ESSDIT  Con atención médica diaria y con especialidade...  7150
#
#                                domicilio sitio_web
# ...

# %%
len(efectores_salud)
# Out:
# 26985

# %%
direcciones_para_georef = [
    {"direccion": row[1]["domicilio"], 
     "provincia_id": str(row[1]["provincia_id"]).zfill(2)}
    for row in efectores_salud[["domicilio", "provincia_id"]].drop_duplicates().iterrows()
]
len(direcciones_para_georef)
# Out:
# 25928

# %%
direcciones_para_georef[:10]
# Out:
# [{'direccion': 'Av. Dindart 852', 'provincia_id': '06'},
#  {'direccion': 'AVENIDA SOLANET e/ SOMIGLIANA y BROWN', 'provincia_id': '06'},
#  {'direccion': 'Saenz Peña e/ Ciano y Dindart', 'provincia_id': '06'},
#  {'direccion': 'Avenida Solanet 718', 'provincia_id': '06'},
#  {'direccion': 'ALMIRANTE BROWN 1369', 'provincia_id': '06'},
#  {'direccion': 'Calle Boero esquina Poderoso', 'provincia_id': '06'},
#  {'direccion': 'Ramsay 2250 (Mendoza y Dragones)', 'provincia_id': '02'},
#  {'direccion': 'Aristóbulo del Valle 1357 PB "A"', 'provincia_id': '02'},
#  {'direccion': 'Laprida 1898 P.B. "H"', 'provincia_id': '02'},
#  {'direccion': 'SANTIAGO DEL ESTERO 1678', 'provincia_id': '02'}]

# %%
def get_similar_bulk(direcciones):
    """Normaliza una lista de nombres de alguna de las entidades geográficas."""
    
    # realiza consulta a la API
    data = {
        "direcciones": [
            {
             "direccion": direccion["direccion"],
             "provincia": direccion["provincia_id"],
             "max": 1,
             "aplanar": True
            } 
            for direccion in direcciones
    ]}
    
    #
    url_endpoint = "https://apis.datos.gob.ar/georef/api/direcciones"
    try:
        results = requests.post(
            url_endpoint, json=data, headers={"Content-Type": "application/json"}
        )
        results_json = results.json()
    except Exception as e:
        print(e)
        print("No se pudieron geolocalizar {} direcciones".format(len(direcciones)))
        return []

    # convierte a una lista de "resultado más probable" o "vacío" cuando no hay
    parsed_results = []
    for single_result, direccion_para_georef in zip(results_json["resultados"], data["direcciones"]):
        if len(single_result["direcciones"]) > 0:
            parsed_result = single_result["direcciones"][0] 
            parsed_result.update(direccion_para_georef)
            parsed_results.append(parsed_result)

    return parsed_results

# %%
import math

# %%
math.ceil(1.2)
# Out:
# 2

# %%
list(range(1000, math.ceil(len(direcciones_para_georef)/1000+1)*1000, 1000))
# Out:
# [1000,
#  2000,
#  3000,
#  4000,
#  5000,
#  6000,
#  7000,
#  8000,
#  9000,
#  10000,
#  11000,
#  12000,
#  13000,
#  14000,
#  15000,
#  16000,
#  17000,
#  18000,
#  19000,
#  20000,
#  21000,
#  22000,
#  23000,
#  24000,
#  25000,
#  26000]

# %%
#%pdb

# %%
direcciones_georreferenciadas = []
for limit in range(1000, math.ceil(len(direcciones_para_georef)/1000+1)*1000, 1000):
    direcciones_georreferenciadas.extend(get_similar_bulk(direcciones_para_georef[limit - 1000:limit]))
# Out:
# Expecting value: line 1 column 1 (char 0)
# No se pudieron geolocalizar 1000 direcciones

# %%
direcciones_georreferenciadas[:2]
# Out:
# [{'altura_unidad': None,
#   'altura_valor': 852,
#   'calle_categoria': 'AV',
#   'calle_cruce_1_categoria': None,
#   'calle_cruce_1_id': None,
#   'calle_cruce_1_nombre': None,
#   'calle_cruce_2_categoria': None,
#   'calle_cruce_2_id': None,
#   'calle_cruce_2_nombre': None,
#   'calle_id': '0604201000075',
#   'calle_nombre': 'AV DINDART',
#   'departamento_id': '06042',
#   'departamento_nombre': 'Ayacucho',
#   'localidad_censal_id': '06042010',
#   'localidad_censal_nombre': 'Ayacucho',
#   'nomenclatura': 'AV DINDART 852, Ayacucho, Buenos Aires',
#   'piso': None,
#   'provincia_id': '06',
#   'provincia_nombre': 'Buenos Aires',
#   'ubicacion_lat': -37.15893485230145,
#   'ubicacion_lon': -58.48938328993407,
#   'direccion': 'Av. Dindart 852',
#   'provincia': '06',
#   'max': 1,
#   'aplanar': True},
#  {'altura_unidad': None,
#   'altura_valor': None,
#   'calle_categoria': 'AV',
#   'calle_cruce_1_categoria': 'CALLE',
#   'calle_cruce_1_id': '0604201000120',
# ...

# %%
pd.DataFrame([
    {"col_1": 1, "col_2": 2}, 
    {"col_1": "b", "col_2": "c"}
])
# Out:
#   col_1 col_2
# 0     1     2
# 1     b     c

# %%
df_direcciones = pd.DataFrame(direcciones_georreferenciadas[:26000])

# %%
len(df_direcciones)
# Out:
# 12683

# %%
df_direcciones.columns
# Out:
# Index(['altura_unidad', 'altura_valor', 'aplanar', 'calle_categoria',
#        'calle_cruce_1_categoria', 'calle_cruce_1_id', 'calle_cruce_1_nombre',
#        'calle_cruce_2_categoria', 'calle_cruce_2_id', 'calle_cruce_2_nombre',
#        'calle_id', 'calle_nombre', 'departamento_id', 'departamento_nombre',
#        'direccion', 'localidad_censal_id', 'localidad_censal_nombre', 'max',
#        'nomenclatura', 'piso', 'provincia', 'provincia_id', 'provincia_nombre',
#        'ubicacion_lat', 'ubicacion_lon'],
#       dtype='object')

# %%
df_direcciones_vf= df_direcciones[["direccion","nomenclatura","provincia", "departamento_nombre","localidad_censal_nombre","ubicacion_lon", "ubicacion_lat"]]
df_direcciones_vf.head(2)
# Out:
#                                direccion  \
# 0                        Av. Dindart 852
# 1  AVENIDA SOLANET e/ SOMIGLIANA y BROWN
#
#                                         nomenclatura provincia  \
# 0             AV DINDART 852, Ayacucho, Buenos Aires        06
# 1  AV PEDRO SOLANET (ENTRE BONIFACIA SOMIGLIANA Y...        06
#
#   departamento_nombre localidad_censal_nombre  ubicacion_lon  ubicacion_lat
# 0            Ayacucho                Ayacucho     -58.489383     -37.158935
# 1            Ayacucho                Ayacucho     -58.473993     -37.151959

# %%
efectores_salud_georef = efectores_salud.drop_duplicates().merge(df_direcciones_vf, left_on="domicilio", right_on="direccion")

# %%
len(efectores_salud_georef)
# Out:
# 13636

# %%
efectores_salud_georef["geometry"]=list(zip(efectores_salud_georef.ubicacion_lon, efectores_salud_georef.ubicacion_lat))
efectores_salud_georef["geometry"] = efectores_salud_georef["geometry"].apply(Point)

# %%
efectores_salud_georef = gpd.GeoDataFrame(efectores_salud_georef)

efectores_salud_georef.plot()
